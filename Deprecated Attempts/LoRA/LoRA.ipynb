# %%
from datasets import load_dataset
from transformers import AutoModelForCausalLM, AutoTokenizer
from peft import get_peft_model, LoraConfig, TaskType
from transformers import TrainingArguments, DataCollatorWithPadding, Trainer

# %%
data_file = "./resume_chatbot_training_data_full.json"
dataset = load_dataset("json", data_files={"train": data_file})

def preprocess_function(example):
    return {
        "input": example["question"],
        "output": example["answer"],
    }

processed_dataset = dataset.map(preprocess_function)
for example in processed_dataset["train"]:
    print(f"Input length: {len(example['input'])}, Output length: {len(example['output'])}")
    print(processed_dataset["train"][0])
# Out:
# Input length: 40, Output length: 195
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 35, Output length: 119
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 38, Output length: 109
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 49, Output length: 61
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 44, Output length: 111
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 49, Output length: 94
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 38, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 49, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 48, Output length: 47
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 71, Output length: 151
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 26, Output length: 171
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 31, Output length: 134
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 61, Output length: 149
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 40, Output length: 148
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 49, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 43, Output length: 92
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 42, Output length: 59
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 34, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 50, Output length: 195
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 45, Output length: 119
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 48, Output length: 109
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 61
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 54, Output length: 111
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 94
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 48, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 58, Output length: 47
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 81, Output length: 151
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 36, Output length: 171
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 41, Output length: 134
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 71, Output length: 149
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 50, Output length: 148
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 53, Output length: 92
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 52, Output length: 59
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 44, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 50, Output length: 195
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 45, Output length: 119
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 48, Output length: 109
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 61
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 54, Output length: 111
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 94
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 48, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 58, Output length: 47
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 81, Output length: 151
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 36, Output length: 171
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 41, Output length: 134
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 71, Output length: 149
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 50, Output length: 148
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 53, Output length: 92
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 52, Output length: 59
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 44, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 60, Output length: 195
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 55, Output length: 119
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 58, Output length: 109
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 69, Output length: 61
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 64, Output length: 111
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 69, Output length: 94
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 58, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 69, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 68, Output length: 47
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 91, Output length: 151
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 46, Output length: 171
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 51, Output length: 134
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 81, Output length: 149
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 60, Output length: 148
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 69, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 63, Output length: 92
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 62, Output length: 59
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 54, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 50, Output length: 195
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 45, Output length: 119
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 48, Output length: 109
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 61
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 54, Output length: 111
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 94
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 48, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 58, Output length: 47
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 81, Output length: 151
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 36, Output length: 171
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 41, Output length: 134
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 71, Output length: 149
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 50, Output length: 148
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 59, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 53, Output length: 92
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 52, Output length: 59
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 44, Output length: 63
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 60, Output length: 195
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 55, Output length: 119
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 58, Output length: 109
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 69, Output length: 61
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 64, Output length: 111
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 69, Output length: 94
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 58, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 69, Output length: 68
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 68, Output length: 47
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}
# Input length: 91, Output length: 151
# {'question': 'What degrees has Aneesh Patne completed?', 'answer': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.', 'input': 'What degrees has Aneesh Patne completed?', 'output': 'Aneesh has completed an M.Tech in Electronics and Telecommunication from Veermata Jijabai Technological Institute and a B.Tech in the same field from Thakur College of Engineering and Technology.'}

# %%
model_path = "D:/Llama-3.2-1B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path)
model = model.to("cuda")
tokenizer.pad_token = tokenizer.eos_token

# %%
lora_config = LoraConfig(
    task_type=TaskType.CAUSAL_LM,  # Language modeling task
    r=16,                         # Rank of update matrices
    lora_alpha=32,                # Scaling factor
    target_modules=["q_proj", "v_proj"],  # Target specific layers
    lora_dropout=0.1              # Dropout rate
)
model = get_peft_model(model, lora_config)

# %%
def tokenize_function(example):
    input_text = f"Q: {example['input']} A: {example['output']}"
    return tokenizer(input_text, truncation=True, padding="max_length", max_length=100)

tokenized_dataset = processed_dataset.map(tokenize_function, batched=True)
tokenized_dataset = tokenized_dataset.remove_columns(["input", "output"])
tokenized_dataset.set_format("torch")
for batch in tokenized_dataset["train"]:
    print(batch["input_ids"].size())
# Out:
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])
# torch.Size([])

# %%
training_args = TrainingArguments(
    output_dir="./lora-resume-chatbot",  # Output directory
    per_device_train_batch_size=4,      # Adjust batch size based on GPU memory
    num_train_epochs=3,                 # Number of training epochs
    learning_rate=5e-4,                 # Learning rate
    logging_dir="./logs",               # Log directory
    logging_steps=10,                   # Log frequency
    save_strategy="epoch",              # Save model at the end of each epoch
    evaluation_strategy="no",        # Evaluate at the end of each epoch
    save_total_limit=2,                 # Limit saved checkpoints
    fp16=True,                           # Enable mixed precision for faster training
    
)
# Out:
# c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\transformers\training_args.py:1575: FutureWarning: `evaluation_strategy` is deprecated and will be removed in version 4.46 of 🤗 Transformers. Use `eval_strategy` instead
#   warnings.warn(

# %%
data_collator = DataCollatorWithPadding(tokenizer=tokenizer, padding="longest")

# %%
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=tokenized_dataset["train"],
    tokenizer=tokenizer,
    data_collator=data_collator
)
# Out:
# C:\Users\anees\AppData\Local\Temp\ipykernel_24852\4052086461.py:1: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `Trainer.__init__`. Use `processing_class` instead.
#   trainer = Trainer(

# %%
trainer.train()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 trainer.train()
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\transformers\trainer.py:2164, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2162         hf_hub_utils.enable_progress_bars()
#    2163 else:
# -> 2164     return inner_training_loop(
#    2165         args=args,
#    2166         resume_from_checkpoint=resume_from_checkpoint,
#    2167         trial=trial,
#    2168         ignore_keys_for_eval=ignore_keys_for_eval,
#    2169     )
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\transformers\trainer.py:2524, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2517 context = (
#    2518     functools.partial(self.accelerator.no_sync, model=model)
#    2519     if i != len(batch_samples) - 1
#    2520     and self.accelerator.distributed_type != DistributedType.DEEPSPEED
#    2521     else contextlib.nullcontext
#    2522 )
#    2523 with context():
# -> 2524     tr_loss_step = self.training_step(model, inputs, num_items_in_batch)
#    2526 if (
#    2527     args.logging_nan_inf_filter
#    2528     and not is_torch_xla_available()
#    2529     and (torch.isnan(tr_loss_step) or torch.isinf(tr_loss_step))
#    2530 ):
#    2531     # if loss is nan or inf simply add the average of previous logged losses
#    2532     tr_loss = tr_loss + tr_loss / (1 + self.state.global_step - self._globalstep_last_logged)
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\transformers\trainer.py:3654, in Trainer.training_step(self, model, inputs, num_items_in_batch)
#    3651     return loss_mb.reduce_mean().detach().to(self.args.device)
#    3653 with self.compute_loss_context_manager():
# -> 3654     loss = self.compute_loss(model, inputs, num_items_in_batch=num_items_in_batch)
#    3656 del inputs
#    3657 if (
#    3658     self.args.torch_empty_cache_steps is not None
#    3659     and self.state.global_step % self.args.torch_empty_cache_steps == 0
#    3660 ):
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\transformers\trainer.py:3708, in Trainer.compute_loss(self, model, inputs, return_outputs, num_items_in_batch)
#    3706         loss_kwargs["num_items_in_batch"] = num_items_in_batch
#    3707     inputs = {**inputs, **loss_kwargs}
# -> 3708 outputs = model(**inputs)
#    3709 # Save past state if it exists
#    3710 # TODO: this needs to be fixed and made cleaner later.
#    3711 if self.args.past_index >= 0:
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\accelerate\utils\operations.py:823, in convert_outputs_to_fp32.<locals>.forward(*args, **kwargs)
#     822 def forward(*args, **kwargs):
# --> 823     return model_forward(*args, **kwargs)
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\accelerate\utils\operations.py:811, in ConvertOutputsToFp32.__call__(self, *args, **kwargs)
#     810 def __call__(self, *args, **kwargs):
# --> 811     return convert_to_fp32(self.model_forward(*args, **kwargs))
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\amp\autocast_mode.py:44, in autocast_decorator.<locals>.decorate_autocast(*args, **kwargs)
#      41 @functools.wraps(func)
#      42 def decorate_autocast(*args, **kwargs):
#      43     with autocast_instance:
# ---> 44         return func(*args, **kwargs)
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\peft\peft_model.py:1719, in PeftModelForCausalLM.forward(self, input_ids, attention_mask, inputs_embeds, labels, output_attentions, output_hidden_states, return_dict, task_ids, **kwargs)
#    1717     with self._enable_peft_forward_hooks(**kwargs):
#    1718         kwargs = {k: v for k, v in kwargs.items() if k not in self.special_peft_forward_args}
# -> 1719         return self.base_model(
#    1720             input_ids=input_ids,
#    1721             attention_mask=attention_mask,
#    1722             inputs_embeds=inputs_embeds,
#    1723             labels=labels,
#    1724             output_attentions=output_attentions,
#    1725             output_hidden_states=output_hidden_states,
#    1726             return_dict=return_dict,
#    1727             **kwargs,
#    1728         )
#    1730 batch_size = _get_batch_size(input_ids, inputs_embeds)
#    1731 if attention_mask is not None:
#    1732     # concat prompt attention mask
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\peft\tuners\tuners_utils.py:197, in BaseTuner.forward(self, *args, **kwargs)
#     196 def forward(self, *args: Any, **kwargs: Any):
# --> 197     return self.model.forward(*args, **kwargs)
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\transformers\models\llama\modeling_llama.py:1163, in LlamaForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, num_logits_to_keep, **kwargs)
#    1160 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#    1162 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# -> 1163 outputs = self.model(
#    1164     input_ids=input_ids,
#    1165     attention_mask=attention_mask,
#    1166     position_ids=position_ids,
#    1167     past_key_values=past_key_values,
#    1168     inputs_embeds=inputs_embeds,
#    1169     use_cache=use_cache,
#    1170     output_attentions=output_attentions,
#    1171     output_hidden_states=output_hidden_states,
#    1172     return_dict=return_dict,
#    1173     cache_position=cache_position,
#    1174     **kwargs,
#    1175 )
#    1177 hidden_states = outputs[0]
#    1178 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\transformers\models\llama\modeling_llama.py:913, in LlamaModel.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     901     layer_outputs = self._gradient_checkpointing_func(
#     902         decoder_layer.__call__,
#     903         hidden_states,
#    (...)
#     910         position_embeddings,
#     911     )
#     912 else:
# --> 913     layer_outputs = decoder_layer(
#     914         hidden_states,
#     915         attention_mask=causal_mask,
#     916         position_ids=position_ids,
#     917         past_key_value=past_key_values,
#     918         output_attentions=output_attentions,
#     919         use_cache=use_cache,
#     920         cache_position=cache_position,
#     921         position_embeddings=position_embeddings,
#     922         **flash_attn_kwargs,
#     923     )
#     925 hidden_states = layer_outputs[0]
#     927 if use_cache:
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\transformers\models\llama\modeling_llama.py:640, in LlamaDecoderLayer.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     637 hidden_states = self.input_layernorm(hidden_states)
#     639 # Self Attention
# --> 640 hidden_states, self_attn_weights, present_key_value = self.self_attn(
#     641     hidden_states=hidden_states,
#     642     attention_mask=attention_mask,
#     643     position_ids=position_ids,
#     644     past_key_value=past_key_value,
#     645     output_attentions=output_attentions,
#     646     use_cache=use_cache,
#     647     cache_position=cache_position,
#     648     position_embeddings=position_embeddings,
#     649     **kwargs,
#     650 )
#     651 hidden_states = residual + hidden_states
#     653 # Fully Connected
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\torch\nn\modules\module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File c:\Users\anees\Desktop\Coding\llmrepo\train-LLAMA\.venv\Lib\site-packages\transformers\models\llama\modeling_llama.py:520, in LlamaSdpaAttention.forward(self, hidden_states, attention_mask, position_ids, past_key_value, output_attentions, use_cache, cache_position, position_embeddings, **kwargs)
#     505     logger.warning_once(
#     506         "LlamaModel is using LlamaSdpaAttention, but `torch.nn.functional.scaled_dot_product_attention` does not support `output_attentions=True`. Falling back to the manual attention implementation, "
#     507         'but specifying the manual implementation will be required from Transformers version v5.0.0 onwards. This warning can be removed using the argument `attn_implementation="eager"` when loading the model.'
#     508     )
#     509     return super().forward(
#     510         hidden_states=hidden_states,
#     511         attention_mask=attention_mask,
#    (...)
#     517         position_embeddings=position_embeddings,
#     518     )
# --> 520 bsz, q_len, _ = hidden_states.size()
#     522 query_states = self.q_proj(hidden_states)
#     523 key_states = self.k_proj(hidden_states)
#
# ValueError: not enough values to unpack (expected 3, got 2)
